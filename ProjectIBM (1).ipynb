# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
#  __Magdalena__
#
#  Social Scientist

# %% [markdown]
# _I'm interested in data science because a data = knowledge_

# %% [markdown]
# ### Add 2+2

# %%
2 + 2
# Out:
# 4

# %% [markdown]
# - R
# - SQL
# - Java
#
# 1. Pandas
# 2. Seaborns
# 3. NumPy
#
#  |Data Science|
# -----------------------
# |Tableau Qlick PowerBI|
